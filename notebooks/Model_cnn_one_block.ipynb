# %% [markdown]
# <a href="https://colab.research.google.com/github/lorenzrossi/MachineLearning/blob/master/Model_cnn_one_block.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from os import listdir
import pandas as pd
# Basic packages
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import pickle

# Image preprocessing
import pathlib
import PIL
import PIL.Image
import cv2

# Neural Networks
import tensorflow as tf
from tensorflow import keras
from keras.utils import to_categorical, load_img, img_to_array
from keras.wrappers.scikit_learn import KerasClassifier
from keras.preprocessing.image import ImageDataGenerator
from keras import models, layers, callbacks, regularizers
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout, Activation
from keras.optimizers import Adam, SGD, RMSprop
from keras.losses import binary_crossentropy
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

# Cross Validation
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import accuracy_score, zero_one_loss

tfk = tf.keras
tf.keras.backend.set_floatx("float64")
# %load_ext tensorboard


from google.colab import drive
drive.mount('/content/drive')

dir = '/content/drive/MyDrive/CatsDogs'
# Out:
# Mounted at /content/drive

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
#%%
X = pickle.load(open('/content/drive/MyDrive/CatsDogs/Pickles/X.pickle','rb'))
y = pickle.load(open('/content/drive/MyDrive/CatsDogs/Pickles/y.pickle','rb'))
#%%
pets_classes = ['Cats','Dogs']

images_to_plot = 8

gray_channel = 0

f, ax = plt.subplots(1, images_to_plot)
f.set_size_inches(30, 20)

for i in range(images_to_plot):
  gray_image = X[i][:, :, gray_channel]
  ax[i].imshow(gray_image, cmap = "gray")
  numeric_label = y[i]
  ax[i].set_title(pets_classes[numeric_label])

# %%
number_of_classes = len(pets_classes)

# %%
x_size, img_dim = X.shape[0], X.shape[1]

# rescale in [0,1]
X = tf.cast(X, tf.float32) / 255.0

# one hot encoding
depth = 1
y = tf.reshape(tf.one_hot(y, depth), shape = [x_size, depth])

# %%
# Train test splitting
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
# Hyperparameters
epoch = 50 # n of epochs
batch = 64 # batch size

# Defining the loss
loss = keras.losses.BinaryCrossentropy(from_logits = True)

# Defining the optimizer(s)
op_1 = Adam()
op_2 = SGD(learning_rate=0.01, momentum=0.9, decay=0.01/50)
op_3 = RMSprop(learning_rate=1e-3)

# %%
# Defining plots
legend_size = 14

def performance_plot(history):
    plt.figure(figsize=(20,8))

    # Loss plots
    plt.subplot(1,2,1)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylabel('loss', size = 12)
    plt.xlabel('epoch', size = 12)
    plt.legend(['train','test'], fontsize = legend_size)

    # Accuracy plots
    plt.subplot(1,2,2)
    plt.plot(history.history['binary_accuracy'])
    plt.plot(history.history['val_binary_accuracy'])
    plt.ylabel('accuracy', size = 12)
    plt.xlabel('epoch', size = 12)
    plt.legend(['train','val'], fontsize = legend_size)

    plt.show()

# %% [markdown]
# # Models
#
# Model 1 is the base architecture
#
# Model 2 adds dropout layers
#
# Model 3 adds batch normalization layers

# %%
model1 = tf.keras.Sequential([
        layers.Conv2D(64, (3, 3), padding = "same", use_bias=False, input_shape = (100, 100, 1), activation='relu'),
        layers.Conv2D(64, (3, 3), padding = "same", use_bias=False, activation='relu'),
        layers.MaxPooling2D(pool_size = (2, 2)),
        layers.Flatten(),
        layers.Dense(128, use_bias=False, activation='relu'),
        layers.Dense(1, activation = 'sigmoid')
        ])
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 64)      576
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 64)      36864
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 64)       0
#  )
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dense (Dense)               (None, 128)               20480000
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 20,517,569
# Trainable params: 20,517,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model1, 'model1.png')

# %%
model2 = tf.keras.Sequential([
        layers.Conv2D(64, (3, 3), padding = "same", use_bias=False, input_shape = (100, 100, 1), activation='relu'),
        layers.Conv2D(64, (3, 3), padding = "same", use_bias=False, activation='relu'),
        layers.MaxPooling2D(pool_size = (2, 2)),
        layers.Dropout(0.25),
        layers.Flatten(),
        layers.Dense(128, use_bias=False, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(1, activation = 'sigmoid')
        ])
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 100, 100, 64)      576
#
#  conv2d_3 (Conv2D)           (None, 100, 100, 64)      36864
#
#  max_pooling2d_1 (MaxPooling  (None, 50, 50, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 50, 50, 64)        0
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 128)               20480000
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 20,517,569
# Trainable params: 20,517,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model2, 'model.png')

# %%
model3 = tf.keras.Sequential([
        layers.Conv2D(64, (3, 3), padding = "same", use_bias=False, input_shape = (100, 100, 1), activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), padding = "same", use_bias=False, activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size = (2, 2)),
        layers.Dropout(0.25),
        layers.Flatten(),
        layers.Dense(128, use_bias=False, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(1, activation = 'sigmoid')
        ])
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 100, 100, 64)      576
#
#  batch_normalization (BatchN  (None, 100, 100, 64)     256
#  ormalization)
#
#  conv2d_5 (Conv2D)           (None, 100, 100, 64)      36864
#
#  batch_normalization_1 (Batc  (None, 100, 100, 64)     256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 50, 50, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 50, 50, 64)        0
#
#  flatten_2 (Flatten)         (None, 160000)            0
#
#  dense_4 (Dense)             (None, 128)               20480000
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 20,518,593
# Trainable params: 20,518,081
# Non-trainable params: 512
# _________________________________________________________________

# %%
keras.utils.plot_model(model3, 'model.png')

# %%
# TRAINING MODEL 1

# compiling the model
model1.compile(optimizer = op_1, loss=loss, metrics=['binary_accuracy'])

history = model1.fit(X_train, y_train, epochs = epoch, batch_size = batch, verbose = 1, validation_data = (X_test, y_test))

performance_plot(history)

result_1 = model1.evaluate(X_test, y_test)
print("test loss, test acc:", result_1)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 313/313 [==============================] - 25s 42ms/step - loss: 0.6809 - binary_accuracy: 0.5943 - val_loss: 0.5909 - val_binary_accuracy: 0.6767
# Epoch 2/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.5263 - binary_accuracy: 0.7398 - val_loss: 0.5445 - val_binary_accuracy: 0.7292
# Epoch 3/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.3677 - binary_accuracy: 0.8370 - val_loss: 0.5485 - val_binary_accuracy: 0.7406
# Epoch 4/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.1839 - binary_accuracy: 0.9298 - val_loss: 0.6735 - val_binary_accuracy: 0.7422
# Epoch 5/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0521 - binary_accuracy: 0.9848 - val_loss: 1.0033 - val_binary_accuracy: 0.7426
# Epoch 6/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0166 - binary_accuracy: 0.9969 - val_loss: 1.2405 - val_binary_accuracy: 0.7410
# Epoch 7/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0072 - binary_accuracy: 0.9987 - val_loss: 1.3606 - val_binary_accuracy: 0.7394
# Epoch 8/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0038 - binary_accuracy: 0.9995 - val_loss: 1.5165 - val_binary_accuracy: 0.7422
# Epoch 9/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0122 - binary_accuracy: 0.9971 - val_loss: 1.4928 - val_binary_accuracy: 0.7318
# Epoch 10/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0133 - binary_accuracy: 0.9964 - val_loss: 1.4650 - val_binary_accuracy: 0.7208
# Epoch 11/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0134 - binary_accuracy: 0.9961 - val_loss: 1.6159 - val_binary_accuracy: 0.7312
# Epoch 12/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0056 - binary_accuracy: 0.9985 - val_loss: 1.8892 - val_binary_accuracy: 0.7342
# Epoch 13/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0097 - binary_accuracy: 0.9969 - val_loss: 1.6203 - val_binary_accuracy: 0.7302
# Epoch 14/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0122 - binary_accuracy: 0.9960 - val_loss: 1.8451 - val_binary_accuracy: 0.7366
# Epoch 15/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0022 - binary_accuracy: 0.9995 - val_loss: 2.0471 - val_binary_accuracy: 0.7326
# Epoch 16/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0023 - binary_accuracy: 0.9992 - val_loss: 1.9151 - val_binary_accuracy: 0.7278
# Epoch 17/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0138 - binary_accuracy: 0.9973 - val_loss: 1.9333 - val_binary_accuracy: 0.7310
# Epoch 18/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0028 - binary_accuracy: 0.9994 - val_loss: 1.8998 - val_binary_accuracy: 0.7384
# Epoch 19/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0019 - binary_accuracy: 0.9995 - val_loss: 2.1739 - val_binary_accuracy: 0.7380
# Epoch 20/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0258 - binary_accuracy: 0.9932 - val_loss: 1.7903 - val_binary_accuracy: 0.7416
# Epoch 21/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0025 - binary_accuracy: 0.9992 - val_loss: 1.9208 - val_binary_accuracy: 0.7334
# Epoch 22/50
# 313/313 [==============================] - 13s 41ms/step - loss: 0.0031 - binary_accuracy: 0.9990 - val_loss: 2.0264 - val_binary_accuracy: 0.7370
# Epoch 23/50
# 313/313 [==============================] - 13s 41ms/step - loss: 4.6072e-04 - binary_accuracy: 1.0000 - val_loss: 2.1937 - val_binary_accuracy: 0.7450
# Epoch 24/50
# 313/313 [==============================] - 13s 41ms/step - loss: 2.2735e-04 - binary_accuracy: 1.0000 - val_loss: 2.2025 - val_binary_accuracy: 0.7472
# Epoch 25/50
# 313/313 [==============================] - 13s 41ms/step - loss: 4.6090e-05 - binary_accuracy: 1.0000 - val_loss: 2.2781 - val_binary_accuracy: 0.7474
# Epoch 26/50
# 313/313 [==============================] - 13s 41ms/step - loss: 3.1112e-05 - binary_accuracy: 1.0000 - val_loss: 2.3309 - val_binary_accuracy: 0.7484
# Epoch 27/50
# 313/313 [==============================] - 13s 41ms/step - loss: 2.3885e-05 - binary_accuracy: 1.0000 - val_loss: 2.3802 - val_binary_accuracy: 0.7488
# Epoch 28/50
# 313/313 [==============================] - 13s 41ms/step - loss: 1.8993e-05 - binary_accuracy: 1.0000 - val_loss: 2.4251 - val_binary_accuracy: 0.7506
# Epoch 29/50
# 313/313 [==============================] - 13s 41ms/step - loss: 1.5296e-05 - binary_accuracy: 1.0000 - val_loss: 2.4658 - val_binary_accuracy: 0.7498
# Epoch 30/50
# 313/313 [==============================] - 13s 41ms/step - loss: 1.3867e-05 - binary_accuracy: 1.0000 - val_loss: 2.5092 - val_binary_accuracy: 0.7494
# Epoch 31/50
# 313/313 [==============================] - 13s 41ms/step - loss: 1.0140e-05 - binary_accuracy: 1.0000 - val_loss: 2.5484 - val_binary_accuracy: 0.7494
# Epoch 32/50
# 313/313 [==============================] - 13s 41ms/step - loss: 8.3428e-06 - binary_accuracy: 1.0000 - val_loss: 2.5855 - val_binary_accuracy: 0.7496
# Epoch 33/50
# 313/313 [==============================] - 13s 41ms/step - loss: 6.9825e-06 - binary_accuracy: 1.0000 - val_loss: 2.6227 - val_binary_accuracy: 0.7492
# Epoch 34/50
# 313/313 [==============================] - 13s 41ms/step - loss: 5.8458e-06 - binary_accuracy: 1.0000 - val_loss: 2.6593 - val_binary_accuracy: 0.7502
# Epoch 35/50
# 313/313 [==============================] - 13s 41ms/step - loss: 4.9578e-06 - binary_accuracy: 1.0000 - val_loss: 2.6957 - val_binary_accuracy: 0.7500
# Epoch 36/50
# 313/313 [==============================] - 13s 41ms/step - loss: 4.2050e-06 - binary_accuracy: 1.0000 - val_loss: 2.7309 - val_binary_accuracy: 0.7504
# Epoch 37/50
# 313/313 [==============================] - 13s 41ms/step - loss: 3.5638e-06 - binary_accuracy: 1.0000 - val_loss: 2.7659 - val_binary_accuracy: 0.7508
# Epoch 38/50
# 313/313 [==============================] - 13s 41ms/step - loss: 3.0258e-06 - binary_accuracy: 1.0000 - val_loss: 2.8020 - val_binary_accuracy: 0.7512
# Epoch 39/50
# 313/313 [==============================] - 13s 41ms/step - loss: 2.5744e-06 - binary_accuracy: 1.0000 - val_loss: 2.8373 - val_binary_accuracy: 0.7504
# Epoch 40/50
# 313/313 [==============================] - 13s 41ms/step - loss: 2.1940e-06 - binary_accuracy: 1.0000 - val_loss: 2.8730 - val_binary_accuracy: 0.7504
# Epoch 41/50
# 313/313 [==============================] - 13s 41ms/step - loss: 1.8588e-06 - binary_accuracy: 1.0000 - val_loss: 2.9050 - val_binary_accuracy: 0.7506
# Epoch 42/50
# 313/313 [==============================] - 13s 41ms/step - loss: 1.5808e-06 - binary_accuracy: 1.0000 - val_loss: 2.9429 - val_binary_accuracy: 0.7510
# Epoch 43/50
# 313/313 [==============================] - 13s 41ms/step - loss: 1.3647e-06 - binary_accuracy: 1.0000 - val_loss: 2.9752 - val_binary_accuracy: 0.7514
# Epoch 44/50
# 313/313 [==============================] - 13s 41ms/step - loss: 1.1472e-06 - binary_accuracy: 1.0000 - val_loss: 3.0115 - val_binary_accuracy: 0.7510
# Epoch 45/50
# 313/313 [==============================] - 13s 41ms/step - loss: 9.8438e-07 - binary_accuracy: 1.0000 - val_loss: 3.0448 - val_binary_accuracy: 0.7504
# Epoch 46/50
# 313/313 [==============================] - 13s 41ms/step - loss: 8.4959e-07 - binary_accuracy: 1.0000 - val_loss: 3.0807 - val_binary_accuracy: 0.7516
# Epoch 47/50
# 313/313 [==============================] - 13s 41ms/step - loss: 7.1066e-07 - binary_accuracy: 1.0000 - val_loss: 3.1159 - val_binary_accuracy: 0.7500
# Epoch 48/50
# 313/313 [==============================] - 13s 41ms/step - loss: 6.1022e-07 - binary_accuracy: 1.0000 - val_loss: 3.1502 - val_binary_accuracy: 0.7500
# Epoch 49/50
# 313/313 [==============================] - 13s 41ms/step - loss: 5.2228e-07 - binary_accuracy: 1.0000 - val_loss: 3.1865 - val_binary_accuracy: 0.7504
# Epoch 50/50
# 313/313 [==============================] - 13s 41ms/step - loss: 4.4250e-07 - binary_accuracy: 1.0000 - val_loss: 3.2205 - val_binary_accuracy: 0.7500
# 157/157 [==============================] - 2s 9ms/step - loss: 3.2205 - binary_accuracy: 0.7500
# test loss, test acc: [3.2204583817819907, 0.75]

# %%
# TRAINING MODEL 2

# compiling the model
model2.compile(optimizer = op_1, loss=loss, metrics=['binary_accuracy'])

history = model2.fit(X_train, y_train, epochs = epoch, batch_size = batch, verbose = 1, validation_data = (X_test, y_test))

performance_plot(history)

result_2 = model2.evaluate(X_test, y_test)
print("test loss, test acc:", result_2)
# Out:
# Epoch 1/50
# 313/313 [==============================] - 14s 43ms/step - loss: 0.7382 - binary_accuracy: 0.5037 - val_loss: 0.6931 - val_binary_accuracy: 0.5084
# Epoch 2/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.6932 - binary_accuracy: 0.5025 - val_loss: 0.6933 - val_binary_accuracy: 0.4918
# Epoch 3/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.6926 - binary_accuracy: 0.5064 - val_loss: 0.6923 - val_binary_accuracy: 0.5006
# Epoch 4/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.6879 - binary_accuracy: 0.5327 - val_loss: 0.6912 - val_binary_accuracy: 0.5108
# Epoch 5/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.6735 - binary_accuracy: 0.5684 - val_loss: 0.6801 - val_binary_accuracy: 0.5733
# Epoch 6/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.6366 - binary_accuracy: 0.6342 - val_loss: 0.6658 - val_binary_accuracy: 0.6143
# Epoch 7/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.5890 - binary_accuracy: 0.6810 - val_loss: 0.6819 - val_binary_accuracy: 0.5979
# Epoch 8/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.5397 - binary_accuracy: 0.7184 - val_loss: 0.6786 - val_binary_accuracy: 0.6437
# Epoch 9/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.4851 - binary_accuracy: 0.7597 - val_loss: 0.7217 - val_binary_accuracy: 0.6245
# Epoch 10/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.4304 - binary_accuracy: 0.7945 - val_loss: 0.7306 - val_binary_accuracy: 0.6453
# Epoch 11/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.3854 - binary_accuracy: 0.8196 - val_loss: 0.7732 - val_binary_accuracy: 0.6457
# Epoch 12/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.3364 - binary_accuracy: 0.8502 - val_loss: 0.8010 - val_binary_accuracy: 0.6423
# Epoch 13/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.3022 - binary_accuracy: 0.8667 - val_loss: 0.8570 - val_binary_accuracy: 0.6431
# Epoch 14/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.2664 - binary_accuracy: 0.8847 - val_loss: 0.9084 - val_binary_accuracy: 0.6417
# Epoch 15/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.2371 - binary_accuracy: 0.8995 - val_loss: 0.9689 - val_binary_accuracy: 0.6405
# Epoch 16/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.2142 - binary_accuracy: 0.9105 - val_loss: 0.9867 - val_binary_accuracy: 0.6421
# Epoch 17/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.1948 - binary_accuracy: 0.9205 - val_loss: 1.0847 - val_binary_accuracy: 0.6367
# Epoch 18/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.1794 - binary_accuracy: 0.9288 - val_loss: 1.1683 - val_binary_accuracy: 0.6363
# Epoch 19/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.1632 - binary_accuracy: 0.9367 - val_loss: 1.0898 - val_binary_accuracy: 0.6453
# Epoch 20/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.1563 - binary_accuracy: 0.9409 - val_loss: 1.2053 - val_binary_accuracy: 0.6413
# Epoch 21/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.1405 - binary_accuracy: 0.9473 - val_loss: 1.3371 - val_binary_accuracy: 0.6413
# Epoch 22/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.1354 - binary_accuracy: 0.9499 - val_loss: 1.2532 - val_binary_accuracy: 0.6495
# Epoch 23/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.1307 - binary_accuracy: 0.9516 - val_loss: 1.2045 - val_binary_accuracy: 0.6471
# Epoch 24/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.1195 - binary_accuracy: 0.9546 - val_loss: 1.3360 - val_binary_accuracy: 0.6463
# Epoch 25/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.1152 - binary_accuracy: 0.9575 - val_loss: 1.2752 - val_binary_accuracy: 0.6493
# Epoch 26/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.1141 - binary_accuracy: 0.9587 - val_loss: 1.3770 - val_binary_accuracy: 0.6421
# Epoch 27/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.1181 - binary_accuracy: 0.9591 - val_loss: 1.3690 - val_binary_accuracy: 0.6413
# Epoch 28/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0961 - binary_accuracy: 0.9652 - val_loss: 1.4087 - val_binary_accuracy: 0.6495
# Epoch 29/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0932 - binary_accuracy: 0.9675 - val_loss: 1.4137 - val_binary_accuracy: 0.6475
# Epoch 30/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0965 - binary_accuracy: 0.9662 - val_loss: 1.5707 - val_binary_accuracy: 0.6459
# Epoch 31/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0990 - binary_accuracy: 0.9661 - val_loss: 1.4569 - val_binary_accuracy: 0.6491
# Epoch 32/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0883 - binary_accuracy: 0.9687 - val_loss: 1.3964 - val_binary_accuracy: 0.6509
# Epoch 33/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0937 - binary_accuracy: 0.9697 - val_loss: 1.4647 - val_binary_accuracy: 0.6443
# Epoch 34/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0844 - binary_accuracy: 0.9700 - val_loss: 1.6145 - val_binary_accuracy: 0.6501
# Epoch 35/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0845 - binary_accuracy: 0.9713 - val_loss: 1.3937 - val_binary_accuracy: 0.6439
# Epoch 36/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0866 - binary_accuracy: 0.9707 - val_loss: 1.5420 - val_binary_accuracy: 0.6485
# Epoch 37/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0763 - binary_accuracy: 0.9736 - val_loss: 1.5040 - val_binary_accuracy: 0.6449
# Epoch 38/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0787 - binary_accuracy: 0.9730 - val_loss: 1.5644 - val_binary_accuracy: 0.6507
# Epoch 39/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0776 - binary_accuracy: 0.9741 - val_loss: 1.5096 - val_binary_accuracy: 0.6513
# Epoch 40/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0747 - binary_accuracy: 0.9737 - val_loss: 1.5002 - val_binary_accuracy: 0.6485
# Epoch 41/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0714 - binary_accuracy: 0.9749 - val_loss: 1.3688 - val_binary_accuracy: 0.6551
# Epoch 42/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0684 - binary_accuracy: 0.9777 - val_loss: 1.5515 - val_binary_accuracy: 0.6511
# Epoch 43/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0684 - binary_accuracy: 0.9764 - val_loss: 1.6805 - val_binary_accuracy: 0.6517
# Epoch 44/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0712 - binary_accuracy: 0.9760 - val_loss: 1.6343 - val_binary_accuracy: 0.6545
# Epoch 45/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0724 - binary_accuracy: 0.9755 - val_loss: 1.4900 - val_binary_accuracy: 0.6483
# Epoch 46/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0668 - binary_accuracy: 0.9769 - val_loss: 1.6012 - val_binary_accuracy: 0.6461
# Epoch 47/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0702 - binary_accuracy: 0.9766 - val_loss: 1.5351 - val_binary_accuracy: 0.6539
# Epoch 48/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0653 - binary_accuracy: 0.9782 - val_loss: 1.6370 - val_binary_accuracy: 0.6469
# Epoch 49/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0695 - binary_accuracy: 0.9764 - val_loss: 1.7139 - val_binary_accuracy: 0.6457
# Epoch 50/50
# 313/313 [==============================] - 13s 42ms/step - loss: 0.0656 - binary_accuracy: 0.9772 - val_loss: 1.6877 - val_binary_accuracy: 0.6429
# 157/157 [==============================] - 2s 10ms/step - loss: 1.6877 - binary_accuracy: 0.6429
# test loss, test acc: [1.6876991191594495, 0.6429143314651722]

# %%
# TRAINING MODEL 3 with Adam

# compiling the model
model3.compile(optimizer = op_1, loss=loss, metrics=['binary_accuracy'])

history = model3.fit(X_train, y_train, epochs = epoch, batch_size = batch, verbose = 1, validation_data = (X_test, y_test))

performance_plot(history)

result_op1 = model3.evaluate(X_test, y_test)
print("test loss, test acc:", result_op1)
# Out:
# Epoch 1/50
# 313/313 [==============================] - 24s 70ms/step - loss: 0.6661 - binary_accuracy: 0.6316 - val_loss: 0.6840 - val_binary_accuracy: 0.5088
# Epoch 2/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.5802 - binary_accuracy: 0.6946 - val_loss: 0.6082 - val_binary_accuracy: 0.6671
# Epoch 3/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.5454 - binary_accuracy: 0.7228 - val_loss: 0.6139 - val_binary_accuracy: 0.6729
# Epoch 4/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.4704 - binary_accuracy: 0.7765 - val_loss: 0.4931 - val_binary_accuracy: 0.7652
# Epoch 5/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.4191 - binary_accuracy: 0.8070 - val_loss: 0.5237 - val_binary_accuracy: 0.7538
# Epoch 6/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.3591 - binary_accuracy: 0.8413 - val_loss: 0.5833 - val_binary_accuracy: 0.7308
# Epoch 7/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.3586 - binary_accuracy: 0.8412 - val_loss: 0.7434 - val_binary_accuracy: 0.6745
# Epoch 8/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.2770 - binary_accuracy: 0.8822 - val_loss: 0.7222 - val_binary_accuracy: 0.7044
# Epoch 9/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.2276 - binary_accuracy: 0.9072 - val_loss: 0.5427 - val_binary_accuracy: 0.7756
# Epoch 10/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.1629 - binary_accuracy: 0.9367 - val_loss: 0.6457 - val_binary_accuracy: 0.7722
# Epoch 11/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.1329 - binary_accuracy: 0.9491 - val_loss: 0.6380 - val_binary_accuracy: 0.7796
# Epoch 12/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.1058 - binary_accuracy: 0.9606 - val_loss: 0.6861 - val_binary_accuracy: 0.7746
# Epoch 13/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.1685 - binary_accuracy: 0.9332 - val_loss: 0.8099 - val_binary_accuracy: 0.7514
# Epoch 14/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.1103 - binary_accuracy: 0.9579 - val_loss: 0.8477 - val_binary_accuracy: 0.7648
# Epoch 15/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0736 - binary_accuracy: 0.9731 - val_loss: 0.7759 - val_binary_accuracy: 0.7676
# Epoch 16/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0663 - binary_accuracy: 0.9768 - val_loss: 0.7648 - val_binary_accuracy: 0.7666
# Epoch 17/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0558 - binary_accuracy: 0.9798 - val_loss: 0.7496 - val_binary_accuracy: 0.7720
# Epoch 18/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0453 - binary_accuracy: 0.9845 - val_loss: 0.8171 - val_binary_accuracy: 0.7788
# Epoch 19/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0381 - binary_accuracy: 0.9868 - val_loss: 0.8311 - val_binary_accuracy: 0.7730
# Epoch 20/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0437 - binary_accuracy: 0.9847 - val_loss: 0.8825 - val_binary_accuracy: 0.7690
# Epoch 21/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0410 - binary_accuracy: 0.9856 - val_loss: 1.5239 - val_binary_accuracy: 0.7218
# Epoch 22/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0450 - binary_accuracy: 0.9846 - val_loss: 0.9947 - val_binary_accuracy: 0.7700
# Epoch 23/50
# 313/313 [==============================] - 22s 69ms/step - loss: 0.0390 - binary_accuracy: 0.9863 - val_loss: 0.9468 - val_binary_accuracy: 0.7806
# Epoch 24/50
# 313/313 [==============================] - 22s 69ms/step - loss: 0.0340 - binary_accuracy: 0.9873 - val_loss: 0.9704 - val_binary_accuracy: 0.7708
# Epoch 25/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0322 - binary_accuracy: 0.9883 - val_loss: 0.9373 - val_binary_accuracy: 0.7734
# Epoch 26/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0363 - binary_accuracy: 0.9868 - val_loss: 0.9593 - val_binary_accuracy: 0.7614
# Epoch 27/50
# 313/313 [==============================] - 22s 69ms/step - loss: 0.0354 - binary_accuracy: 0.9865 - val_loss: 0.9052 - val_binary_accuracy: 0.7684
# Epoch 28/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0369 - binary_accuracy: 0.9870 - val_loss: 1.0503 - val_binary_accuracy: 0.7708
# Epoch 29/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0278 - binary_accuracy: 0.9909 - val_loss: 1.0861 - val_binary_accuracy: 0.7656
# Epoch 30/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0303 - binary_accuracy: 0.9894 - val_loss: 0.9835 - val_binary_accuracy: 0.7784
# Epoch 31/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0240 - binary_accuracy: 0.9916 - val_loss: 0.9729 - val_binary_accuracy: 0.7786
# Epoch 32/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0240 - binary_accuracy: 0.9917 - val_loss: 0.9482 - val_binary_accuracy: 0.7744
# Epoch 33/50
# 313/313 [==============================] - 22s 69ms/step - loss: 0.0279 - binary_accuracy: 0.9906 - val_loss: 1.2821 - val_binary_accuracy: 0.7500
# Epoch 34/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0301 - binary_accuracy: 0.9891 - val_loss: 1.0582 - val_binary_accuracy: 0.7734
# Epoch 35/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0239 - binary_accuracy: 0.9910 - val_loss: 0.9147 - val_binary_accuracy: 0.7806
# Epoch 36/50
# 313/313 [==============================] - 22s 69ms/step - loss: 0.0260 - binary_accuracy: 0.9905 - val_loss: 0.9422 - val_binary_accuracy: 0.7756
# Epoch 37/50
# 313/313 [==============================] - 22s 69ms/step - loss: 0.0237 - binary_accuracy: 0.9910 - val_loss: 0.9940 - val_binary_accuracy: 0.7802
# Epoch 38/50
# 313/313 [==============================] - 22s 69ms/step - loss: 0.0236 - binary_accuracy: 0.9916 - val_loss: 1.1730 - val_binary_accuracy: 0.7784
# Epoch 39/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0207 - binary_accuracy: 0.9927 - val_loss: 0.9021 - val_binary_accuracy: 0.7584
# Epoch 40/50
# 313/313 [==============================] - 22s 69ms/step - loss: 0.0263 - binary_accuracy: 0.9902 - val_loss: 1.0936 - val_binary_accuracy: 0.7744
# Epoch 41/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0189 - binary_accuracy: 0.9940 - val_loss: 0.9658 - val_binary_accuracy: 0.7834
# Epoch 42/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0240 - binary_accuracy: 0.9911 - val_loss: 1.0867 - val_binary_accuracy: 0.7806
# Epoch 43/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0211 - binary_accuracy: 0.9923 - val_loss: 1.0361 - val_binary_accuracy: 0.7844
# Epoch 44/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0221 - binary_accuracy: 0.9924 - val_loss: 1.0914 - val_binary_accuracy: 0.7794
# Epoch 45/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0191 - binary_accuracy: 0.9936 - val_loss: 1.0142 - val_binary_accuracy: 0.7888
# Epoch 46/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0179 - binary_accuracy: 0.9933 - val_loss: 1.1720 - val_binary_accuracy: 0.7768
# Epoch 47/50
# 313/313 [==============================] - 22s 69ms/step - loss: 0.0175 - binary_accuracy: 0.9933 - val_loss: 1.0557 - val_binary_accuracy: 0.7768
# Epoch 48/50
# 313/313 [==============================] - 22s 69ms/step - loss: 0.0263 - binary_accuracy: 0.9904 - val_loss: 1.0885 - val_binary_accuracy: 0.7848
# Epoch 49/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0176 - binary_accuracy: 0.9934 - val_loss: 1.4497 - val_binary_accuracy: 0.7730
# Epoch 50/50
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0201 - binary_accuracy: 0.9926 - val_loss: 1.0936 - val_binary_accuracy: 0.7686
# 157/157 [==============================] - 2s 11ms/step - loss: 1.0936 - binary_accuracy: 0.7686
# test loss, test acc: [1.0936316729732247, 0.7686148919135308]
